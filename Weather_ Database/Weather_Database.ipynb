# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#from citipy import citipy
# Import the API key.
#from config import weather_api_key
# Import the requests library.
#import requests

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy 

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
     city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
     if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 728

# %%
#Import APIkey
from config import weather_api_key

# Import the datetime module from the datetime library.

from datetime import datetime

# Import the requests library.
import requests

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50 ):
        set_count += 1
        record_count = 1
      
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    #print(city_url)
     
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
     # Parse the JSON and retrieve data.
    city_weather = requests.get(city_url).json()
 # Run an API request for each of the cities.
    try:
    
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
     
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

    
 # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | solnechnyy
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | prince rupert
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | broken hill
# Processing Record 8 of Set 1 | mar del plata
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | jhargram
# Processing Record 12 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 1 | sinnamary
# Processing Record 14 of Set 1 | atherton
# Processing Record 15 of Set 1 | san angelo
# Processing Record 16 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | enumclaw
# Processing Record 19 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 1 | tasiilaq
# Processing Record 21 of Set 1 | kibala
# Processing Record 22 of Set 1 | baracoa
# Processing Record 23 of Set 1 | casa nova
# Processing Record 24 of Set 1 | tuatapere
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | bathsheba
# Processing Record 27 of Set 1 | san cristobal
# Processing Record 28 of Set 1 | mizdah
# Processing Record 29 of Set 1 | sao filipe
# Processing Record 30 of Set 1 | rio gallegos
# Processing Record 31 of Set 1 | provideniya
# Processing Record 32 of Set 1 | lebu
# Processing Record 33 of Set 1 | norman wells
# Processing Record 34 of Set 1 | sembe
# Processing Record 35 of Set 1 | alofi
# Processing Record 36 of Set 1 | pahrump
# Processing Record 37 of Set 1 | tuktoyaktuk
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | kodiak
# Processing Record 40 of Set 1 | barrow
# Processing Record 41 of Set 1 | inirida
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | zelezny brod
# Processing Record 44 of Set 1 | jinchang
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | port elizabeth
# Processing Record 48 of Set 1 | iqaluit
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | kahului
# Processing Record 1 of Set 2 | andevoranto
# City not found. Skipping...
# Processing Record 2 of Set 2 | vila
# Processing Record 3 of Set 2 | saint-leu
# Processing Record 4 of Set 2 | dong xoai
# Processing Record 5 of Set 2 | gonbad-e qabus
# Processing Record 6 of Set 2 | morant bay
# Processing Record 7 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 2 | richards bay
# Processing Record 9 of Set 2 | melito di porto salvo
# Processing Record 10 of Set 2 | emerald
# Processing Record 11 of Set 2 | port-gentil
# Processing Record 12 of Set 2 | atuona
# Processing Record 13 of Set 2 | khatanga
# Processing Record 14 of Set 2 | ler
# Processing Record 15 of Set 2 | qaanaaq
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 2 | punta arenas
# Processing Record 19 of Set 2 | fairbanks
# Processing Record 20 of Set 2 | biloela
# Processing Record 21 of Set 2 | severo-kurilsk
# Processing Record 22 of Set 2 | fortuna
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | pochutla
# Processing Record 25 of Set 2 | vaini
# Processing Record 26 of Set 2 | klaksvik
# Processing Record 27 of Set 2 | askarovo
# Processing Record 28 of Set 2 | lazaro cardenas
# Processing Record 29 of Set 2 | mudgee
# Processing Record 30 of Set 2 | buchanan
# Processing Record 31 of Set 2 | vernon
# Processing Record 32 of Set 2 | te anau
# Processing Record 33 of Set 2 | nantucket
# Processing Record 34 of Set 2 | chokurdakh
# Processing Record 35 of Set 2 | ionia
# Processing Record 36 of Set 2 | hermanus
# Processing Record 37 of Set 2 | kudahuvadhoo
# Processing Record 38 of Set 2 | mareeba
# Processing Record 39 of Set 2 | husavik
# Processing Record 40 of Set 2 | hamilton
# Processing Record 41 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 2 | arraial do cabo
# Processing Record 43 of Set 2 | torbay
# Processing Record 44 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 2 | buala
# Processing Record 46 of Set 2 | abu samrah
# Processing Record 47 of Set 2 | grajau
# Processing Record 48 of Set 2 | butaritari
# Processing Record 49 of Set 2 | hundested
# Processing Record 50 of Set 2 | dunedin
# Processing Record 1 of Set 3 | kybartai
# Processing Record 2 of Set 3 | taburi
# City not found. Skipping...
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | bredasdorp
# Processing Record 5 of Set 3 | petropavlovka
# Processing Record 6 of Set 3 | plaster rock
# Processing Record 7 of Set 3 | salalah
# Processing Record 8 of Set 3 | methoni
# Processing Record 9 of Set 3 | russkaya polyana
# Processing Record 10 of Set 3 | isernia
# Processing Record 11 of Set 3 | mana
# Processing Record 12 of Set 3 | tecoanapa
# Processing Record 13 of Set 3 | dikson
# Processing Record 14 of Set 3 | belousovka
# Processing Record 15 of Set 3 | kerki
# City not found. Skipping...
# Processing Record 16 of Set 3 | palmer
# Processing Record 17 of Set 3 | port lincoln
# Processing Record 18 of Set 3 | manoel urbano
# Processing Record 19 of Set 3 | katsuura
# Processing Record 20 of Set 3 | longyearbyen
# Processing Record 21 of Set 3 | bambous virieux
# Processing Record 22 of Set 3 | hithadhoo
# Processing Record 23 of Set 3 | mansa
# Processing Record 24 of Set 3 | taltal
# Processing Record 25 of Set 3 | isangel
# Processing Record 26 of Set 3 | san patricio
# Processing Record 27 of Set 3 | saskylakh
# Processing Record 28 of Set 3 | pirayu
# Processing Record 29 of Set 3 | zhangye
# Processing Record 30 of Set 3 | deputatskiy
# Processing Record 31 of Set 3 | altea
# Processing Record 32 of Set 3 | wynyard
# Processing Record 33 of Set 3 | bethel
# Processing Record 34 of Set 3 | ndungu
# Processing Record 35 of Set 3 | carballo
# Processing Record 36 of Set 3 | ancud
# Processing Record 37 of Set 3 | lasa
# Processing Record 38 of Set 3 | porto novo
# Processing Record 39 of Set 3 | san quintin
# Processing Record 40 of Set 3 | saint george
# Processing Record 41 of Set 3 | chuy
# Processing Record 42 of Set 3 | purranque
# Processing Record 43 of Set 3 | berlevag
# Processing Record 44 of Set 3 | grand island
# Processing Record 45 of Set 3 | kaitangata
# Processing Record 46 of Set 3 | college
# Processing Record 47 of Set 3 | port hardy
# Processing Record 48 of Set 3 | tiksi
# Processing Record 49 of Set 3 | baoqing
# Processing Record 50 of Set 3 | talnakh
# Processing Record 1 of Set 4 | lillooet
# Processing Record 2 of Set 4 | dillon
# Processing Record 3 of Set 4 | hervey bay
# Processing Record 4 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 4 | ilulissat
# Processing Record 6 of Set 4 | beisfjord
# Processing Record 7 of Set 4 | swan river
# Processing Record 8 of Set 4 | mahebourg
# Processing Record 9 of Set 4 | dicabisagan
# Processing Record 10 of Set 4 | sulangan
# Processing Record 11 of Set 4 | huanren
# Processing Record 12 of Set 4 | gavle
# Processing Record 13 of Set 4 | port hedland
# Processing Record 14 of Set 4 | amapa
# Processing Record 15 of Set 4 | victoria
# Processing Record 16 of Set 4 | pinas
# Processing Record 17 of Set 4 | airai
# Processing Record 18 of Set 4 | lata
# Processing Record 19 of Set 4 | manjakandriana
# Processing Record 20 of Set 4 | chaoyang
# Processing Record 21 of Set 4 | bengkulu
# Processing Record 22 of Set 4 | nadym
# Processing Record 23 of Set 4 | russell
# Processing Record 24 of Set 4 | souillac
# Processing Record 25 of Set 4 | guerrero negro
# Processing Record 26 of Set 4 | patiya
# Processing Record 27 of Set 4 | nuuk
# Processing Record 28 of Set 4 | pisco
# Processing Record 29 of Set 4 | sfantu gheorghe
# Processing Record 30 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 4 | pontes e lacerda
# Processing Record 32 of Set 4 | manakara
# Processing Record 33 of Set 4 | dauphin
# Processing Record 34 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 4 | cabo san lucas
# Processing Record 36 of Set 4 | pionerskiy
# Processing Record 37 of Set 4 | hobart
# Processing Record 38 of Set 4 | cambridge
# Processing Record 39 of Set 4 | cherskiy
# Processing Record 40 of Set 4 | lardos
# Processing Record 41 of Set 4 | cap malheureux
# Processing Record 42 of Set 4 | zonguldak
# Processing Record 43 of Set 4 | nikolskoye
# Processing Record 44 of Set 4 | sitka
# Processing Record 45 of Set 4 | lagos
# Processing Record 46 of Set 4 | praia da vitoria
# Processing Record 47 of Set 4 | port alfred
# Processing Record 48 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 49 of Set 4 | borovichi
# Processing Record 50 of Set 4 | hovd
# Processing Record 1 of Set 5 | blythe
# Processing Record 2 of Set 5 | ornskoldsvik
# Processing Record 3 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 5 | hambantota
# Processing Record 5 of Set 5 | bluff
# Processing Record 6 of Set 5 | bin qirdan
# Processing Record 7 of Set 5 | mae sai
# Processing Record 8 of Set 5 | venezuela
# Processing Record 9 of Set 5 | susanville
# Processing Record 10 of Set 5 | mopipi
# Processing Record 11 of Set 5 | touros
# Processing Record 12 of Set 5 | akmene
# Processing Record 13 of Set 5 | alyangula
# Processing Record 14 of Set 5 | honiara
# Processing Record 15 of Set 5 | nichinan
# Processing Record 16 of Set 5 | shelbyville
# Processing Record 17 of Set 5 | gananoque
# Processing Record 18 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 19 of Set 5 | kilindoni
# Processing Record 20 of Set 5 | tynset
# Processing Record 21 of Set 5 | para de minas
# Processing Record 22 of Set 5 | thompson
# Processing Record 23 of Set 5 | terrell
# Processing Record 24 of Set 5 | carnarvon
# Processing Record 25 of Set 5 | itoman
# Processing Record 26 of Set 5 | leningradskiy
# Processing Record 27 of Set 5 | naryan-mar
# Processing Record 28 of Set 5 | camas
# Processing Record 29 of Set 5 | aragats
# Processing Record 30 of Set 5 | matara
# Processing Record 31 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 32 of Set 5 | teeli
# Processing Record 33 of Set 5 | mandalgovi
# Processing Record 34 of Set 5 | bend
# Processing Record 35 of Set 5 | bida
# Processing Record 36 of Set 5 | basar
# Processing Record 37 of Set 5 | la ronge
# Processing Record 38 of Set 5 | villa carlos paz
# Processing Record 39 of Set 5 | arona
# Processing Record 40 of Set 5 | charters towers
# Processing Record 41 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 42 of Set 5 | hurghada
# Processing Record 43 of Set 5 | codrington
# Processing Record 44 of Set 5 | chokwe
# Processing Record 45 of Set 5 | nouadhibou
# Processing Record 46 of Set 5 | auki
# Processing Record 47 of Set 5 | mackenzie
# Processing Record 48 of Set 5 | tongchuan
# Processing Record 49 of Set 5 | ribeira grande
# Processing Record 50 of Set 5 | la rioja
# Processing Record 1 of Set 6 | dandong
# Processing Record 2 of Set 6 | henties bay
# Processing Record 3 of Set 6 | maceio
# Processing Record 4 of Set 6 | vestmannaeyjar
# Processing Record 5 of Set 6 | avon
# Processing Record 6 of Set 6 | praia
# Processing Record 7 of Set 6 | acajutla
# Processing Record 8 of Set 6 | yumen
# Processing Record 9 of Set 6 | kavieng
# Processing Record 10 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 6 | avera
# Processing Record 12 of Set 6 | ostersund
# Processing Record 13 of Set 6 | verkhniy ufaley
# Processing Record 14 of Set 6 | upernavik
# Processing Record 15 of Set 6 | saint-joseph
# Processing Record 16 of Set 6 | kieta
# Processing Record 17 of Set 6 | harper
# Processing Record 18 of Set 6 | muros
# Processing Record 19 of Set 6 | san rafael del sur
# Processing Record 20 of Set 6 | hendersonville
# Processing Record 21 of Set 6 | itabira
# Processing Record 22 of Set 6 | hofn
# Processing Record 23 of Set 6 | gizo
# Processing Record 24 of Set 6 | halifax
# Processing Record 25 of Set 6 | saldanha
# Processing Record 26 of Set 6 | mahibadhoo
# Processing Record 27 of Set 6 | cockburn town
# Processing Record 28 of Set 6 | paucartambo
# City not found. Skipping...
# Processing Record 29 of Set 6 | kargat
# Processing Record 30 of Set 6 | kruisfontein
# Processing Record 31 of Set 6 | bosaso
# Processing Record 32 of Set 6 | nanortalik
# Processing Record 33 of Set 6 | taoudenni
# Processing Record 34 of Set 6 | namatanai
# Processing Record 35 of Set 6 | ambilobe
# Processing Record 36 of Set 6 | hasaki
# Processing Record 37 of Set 6 | mabaruma
# Processing Record 38 of Set 6 | rodrigues alves
# Processing Record 39 of Set 6 | dabat
# Processing Record 40 of Set 6 | cabedelo
# Processing Record 41 of Set 6 | nurobod
# Processing Record 42 of Set 6 | shimizu
# Processing Record 43 of Set 6 | bima
# Processing Record 44 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 6 | inhambane
# Processing Record 46 of Set 6 | rocha
# Processing Record 47 of Set 6 | jalu
# Processing Record 48 of Set 6 | progreso
# Processing Record 49 of Set 6 | juneau
# Processing Record 50 of Set 6 | mabopane
# Processing Record 1 of Set 7 | luderitz
# Processing Record 2 of Set 7 | tura
# Processing Record 3 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 7 | vila franca do campo
# Processing Record 5 of Set 7 | chapais
# Processing Record 6 of Set 7 | sur
# Processing Record 7 of Set 7 | ust-kuyga
# Processing Record 8 of Set 7 | kutum
# Processing Record 9 of Set 7 | okhotsk
# Processing Record 10 of Set 7 | kawana waters
# City not found. Skipping...
# Processing Record 11 of Set 7 | phulabani
# Processing Record 12 of Set 7 | saint anthony
# Processing Record 13 of Set 7 | salina
# Processing Record 14 of Set 7 | fort nelson
# Processing Record 15 of Set 7 | sonqor
# Processing Record 16 of Set 7 | krasnopillya
# Processing Record 17 of Set 7 | kamina
# Processing Record 18 of Set 7 | conakry
# Processing Record 19 of Set 7 | kamenka
# Processing Record 20 of Set 7 | ponta do sol
# Processing Record 21 of Set 7 | bandarbeyla
# Processing Record 22 of Set 7 | hvolsvollur
# Processing Record 23 of Set 7 | batagay-alyta
# Processing Record 24 of Set 7 | north bend
# Processing Record 25 of Set 7 | belmonte
# Processing Record 26 of Set 7 | labuhan
# Processing Record 27 of Set 7 | kautokeino
# Processing Record 28 of Set 7 | emet
# Processing Record 29 of Set 7 | luena
# Processing Record 30 of Set 7 | sao jose da coroa grande
# Processing Record 31 of Set 7 | winnemucca
# Processing Record 32 of Set 7 | mpongwe
# Processing Record 33 of Set 7 | turayf
# Processing Record 34 of Set 7 | cayenne
# Processing Record 35 of Set 7 | marystown
# Processing Record 36 of Set 7 | esperance
# Processing Record 37 of Set 7 | karimpur
# Processing Record 38 of Set 7 | hagi
# Processing Record 39 of Set 7 | bilibino
# Processing Record 40 of Set 7 | tautira
# Processing Record 41 of Set 7 | nagornskiy
# Processing Record 42 of Set 7 | evensk
# Processing Record 43 of Set 7 | tsiroanomandidy
# Processing Record 44 of Set 7 | grootfontein
# Processing Record 45 of Set 7 | hualmay
# Processing Record 46 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 47 of Set 7 | yining
# Processing Record 48 of Set 7 | port augusta
# Processing Record 49 of Set 7 | itarema
# Processing Record 50 of Set 7 | naze
# Processing Record 1 of Set 8 | neiafu
# Processing Record 2 of Set 8 | morondava
# Processing Record 3 of Set 8 | narsaq
# Processing Record 4 of Set 8 | barra do garcas
# Processing Record 5 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 6 of Set 8 | havre
# Processing Record 7 of Set 8 | wuzhou
# Processing Record 8 of Set 8 | sept-iles
# Processing Record 9 of Set 8 | langsa
# Processing Record 10 of Set 8 | georgetown
# Processing Record 11 of Set 8 | wang saphung
# Processing Record 12 of Set 8 | meulaboh
# Processing Record 13 of Set 8 | apad
# Processing Record 14 of Set 8 | port hawkesbury
# Processing Record 15 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 8 | gat
# Processing Record 17 of Set 8 | langham
# Processing Record 18 of Set 8 | westport
# Processing Record 19 of Set 8 | aykhal
# Processing Record 20 of Set 8 | bredy
# Processing Record 21 of Set 8 | nioro
# Processing Record 22 of Set 8 | xuddur
# Processing Record 23 of Set 8 | broome
# Processing Record 24 of Set 8 | jingdezhen
# Processing Record 25 of Set 8 | kandi
# Processing Record 26 of Set 8 | galgani
# City not found. Skipping...
# Processing Record 27 of Set 8 | slavyanka
# Processing Record 28 of Set 8 | caarapo
# Processing Record 29 of Set 8 | florida
# Processing Record 30 of Set 8 | casablanca
# Processing Record 31 of Set 8 | pangnirtung
# Processing Record 32 of Set 8 | mehamn
# Processing Record 33 of Set 8 | pevek
# Processing Record 34 of Set 8 | marawi
# Processing Record 35 of Set 8 | lorengau
# Processing Record 36 of Set 8 | yunjinghong
# City not found. Skipping...
# Processing Record 37 of Set 8 | tessalit
# Processing Record 38 of Set 8 | kaeng khoi
# Processing Record 39 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 8 | alice springs
# Processing Record 41 of Set 8 | develi
# Processing Record 42 of Set 8 | mayumba
# Processing Record 43 of Set 8 | the hammocks
# Processing Record 44 of Set 8 | padang
# Processing Record 45 of Set 8 | tomatlan
# Processing Record 46 of Set 8 | sharon
# Processing Record 47 of Set 8 | kuytun
# Processing Record 48 of Set 8 | castro
# Processing Record 49 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 50 of Set 8 | bahia blanca
# Processing Record 1 of Set 9 | clyde river
# Processing Record 2 of Set 9 | yulara
# Processing Record 3 of Set 9 | aklavik
# Processing Record 4 of Set 9 | geraldton
# Processing Record 5 of Set 9 | kloulklubed
# Processing Record 6 of Set 9 | skibbereen
# Processing Record 7 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 8 of Set 9 | pingdingshan
# Processing Record 9 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 9 | balikpapan
# Processing Record 11 of Set 9 | kamaishi
# Processing Record 12 of Set 9 | bridgetown
# Processing Record 13 of Set 9 | jambi
# Processing Record 14 of Set 9 | vadso
# Processing Record 15 of Set 9 | aksay
# Processing Record 16 of Set 9 | langres
# Processing Record 17 of Set 9 | altay
# Processing Record 18 of Set 9 | portland
# Processing Record 19 of Set 9 | najran
# Processing Record 20 of Set 9 | vogan
# Processing Record 21 of Set 9 | vardo
# Processing Record 22 of Set 9 | contamana
# Processing Record 23 of Set 9 | cluses
# Processing Record 24 of Set 9 | necochea
# Processing Record 25 of Set 9 | ust-omchug
# Processing Record 26 of Set 9 | coahuayana
# Processing Record 27 of Set 9 | willowmore
# Processing Record 28 of Set 9 | ilebo
# Processing Record 29 of Set 9 | faanui
# Processing Record 30 of Set 9 | svobodnyy
# Processing Record 31 of Set 9 | steamboat springs
# Processing Record 32 of Set 9 | xining
# Processing Record 33 of Set 9 | dingle
# Processing Record 34 of Set 9 | umm kaddadah
# Processing Record 35 of Set 9 | pacific grove
# Processing Record 36 of Set 9 | kalmar
# Processing Record 37 of Set 9 | graaff-reinet
# Processing Record 38 of Set 9 | mandal
# Processing Record 39 of Set 9 | hauterive
# Processing Record 40 of Set 9 | makakilo city
# Processing Record 41 of Set 9 | raudeberg
# Processing Record 42 of Set 9 | young
# Processing Record 43 of Set 9 | tikapur
# Processing Record 44 of Set 9 | tevaitoa
# Processing Record 45 of Set 9 | tabriz
# Processing Record 46 of Set 9 | vila velha
# Processing Record 47 of Set 9 | sassandra
# Processing Record 48 of Set 9 | shenjiamen
# Processing Record 49 of Set 9 | port blair
# Processing Record 50 of Set 9 | langue
# Processing Record 1 of Set 10 | kologriv
# Processing Record 2 of Set 10 | smithers
# Processing Record 3 of Set 10 | aloleng
# Processing Record 4 of Set 10 | ust-maya
# Processing Record 5 of Set 10 | silifke
# Processing Record 6 of Set 10 | vanavara
# Processing Record 7 of Set 10 | morgan city
# Processing Record 8 of Set 10 | moranbah
# Processing Record 9 of Set 10 | bad wurzach
# Processing Record 10 of Set 10 | khabary
# Processing Record 11 of Set 10 | zhanatas
# City not found. Skipping...
# Processing Record 12 of Set 10 | maniitsoq
# Processing Record 13 of Set 10 | yarmouth
# Processing Record 14 of Set 10 | trelew
# Processing Record 15 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 16 of Set 10 | gamba
# Processing Record 17 of Set 10 | bannu
# Processing Record 18 of Set 10 | mount isa
# Processing Record 19 of Set 10 | shache
# Processing Record 20 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 10 | rabo de peixe
# Processing Record 22 of Set 10 | sangar
# Processing Record 23 of Set 10 | lavrentiya
# Processing Record 24 of Set 10 | lichtenburg
# Processing Record 25 of Set 10 | camana
# Processing Record 26 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 10 | plateros
# Processing Record 28 of Set 10 | hisor
# Processing Record 29 of Set 10 | goure
# Processing Record 30 of Set 10 | staryy nadym
# Processing Record 31 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 10 | nuevo progreso
# Processing Record 33 of Set 10 | walla walla
# Processing Record 34 of Set 10 | laguna
# Processing Record 35 of Set 10 | jilotzingo
# Processing Record 36 of Set 10 | tselinnoye
# Processing Record 37 of Set 10 | punto fijo
# Processing Record 38 of Set 10 | asau
# Processing Record 39 of Set 10 | gaborone
# Processing Record 40 of Set 10 | ostrovnoy
# Processing Record 41 of Set 10 | benevento
# Processing Record 42 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 43 of Set 10 | sao gabriel da cachoeira
# Processing Record 44 of Set 10 | acapulco
# Processing Record 45 of Set 10 | rochester
# Processing Record 46 of Set 10 | marzuq
# Processing Record 47 of Set 10 | bressanone
# Processing Record 48 of Set 10 | bambanglipuro
# Processing Record 49 of Set 10 | bonthe
# Processing Record 50 of Set 10 | saint-paul
# Processing Record 1 of Set 11 | kavaratti
# Processing Record 2 of Set 11 | lompoc
# Processing Record 3 of Set 11 | motala
# Processing Record 4 of Set 11 | abancay
# Processing Record 5 of Set 11 | vanimo
# Processing Record 6 of Set 11 | turukhansk
# Processing Record 7 of Set 11 | almeirim
# Processing Record 8 of Set 11 | wahiawa
# Processing Record 9 of Set 11 | xinyu
# Processing Record 10 of Set 11 | teguise
# Processing Record 11 of Set 11 | cidreira
# Processing Record 12 of Set 11 | namanyere
# Processing Record 13 of Set 11 | loikaw
# Processing Record 14 of Set 11 | manadhoo
# Processing Record 15 of Set 11 | ulladulla
# Processing Record 16 of Set 11 | milingimbi
# City not found. Skipping...
# Processing Record 17 of Set 11 | orlik
# Processing Record 18 of Set 11 | samarai
# Processing Record 19 of Set 11 | hirara
# Processing Record 20 of Set 11 | hay river
# Processing Record 21 of Set 11 | prieska
# Processing Record 22 of Set 11 | northam
# Processing Record 23 of Set 11 | paita
# Processing Record 24 of Set 11 | high level
# Processing Record 25 of Set 11 | beloha
# Processing Record 26 of Set 11 | daud khel
# Processing Record 27 of Set 11 | ures
# Processing Record 28 of Set 11 | sibu
# Processing Record 29 of Set 11 | saint-augustin
# Processing Record 30 of Set 11 | angoche
# Processing Record 31 of Set 11 | xiaolan
# Processing Record 32 of Set 11 | ahipara
# Processing Record 33 of Set 11 | zyryanka
# Processing Record 34 of Set 11 | santa vitoria do palmar
# Processing Record 35 of Set 11 | constitucion
# Processing Record 36 of Set 11 | tynda
# Processing Record 37 of Set 11 | conceicao do araguaia
# Processing Record 38 of Set 11 | yangjiang
# Processing Record 39 of Set 11 | sambava
# Processing Record 40 of Set 11 | komsomolskiy
# Processing Record 41 of Set 11 | harrisonville
# Processing Record 42 of Set 11 | kysyl-syr
# Processing Record 43 of Set 11 | chimbote
# Processing Record 44 of Set 11 | sioux lookout
# Processing Record 45 of Set 11 | kupang
# Processing Record 46 of Set 11 | oktyabrskiy
# Processing Record 47 of Set 11 | shimoda
# Processing Record 48 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 11 | great yarmouth
# Processing Record 1 of Set 12 | chibuto
# Processing Record 2 of Set 12 | tateyama
# Processing Record 3 of Set 12 | arys
# Processing Record 4 of Set 12 | kozulka
# Processing Record 5 of Set 12 | maun
# Processing Record 6 of Set 12 | lae
# Processing Record 7 of Set 12 | houma
# Processing Record 8 of Set 12 | sarakhs
# Processing Record 9 of Set 12 | santiago
# Processing Record 10 of Set 12 | ghorawal
# Processing Record 11 of Set 12 | dzhebariki-khaya
# Processing Record 12 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 13 of Set 12 | burnie
# Processing Record 14 of Set 12 | lensk
# Processing Record 15 of Set 12 | kuching
# Processing Record 16 of Set 12 | talakan
# Processing Record 17 of Set 12 | zhigansk
# Processing Record 18 of Set 12 | chapleau
# Processing Record 19 of Set 12 | irece
# Processing Record 20 of Set 12 | kurchum
# Processing Record 21 of Set 12 | palaikastron
# Processing Record 22 of Set 12 | cairns
# Processing Record 23 of Set 12 | podsineye
# Processing Record 24 of Set 12 | mogadishu
# Processing Record 25 of Set 12 | novikovo
# Processing Record 26 of Set 12 | lagoa
# Processing Record 27 of Set 12 | banjarmasin
# Processing Record 28 of Set 12 | jacareacanga
# Processing Record 29 of Set 12 | mayo
# Processing Record 30 of Set 12 | three hills
# Processing Record 31 of Set 12 | jackson
# Processing Record 32 of Set 12 | barcelona
# Processing Record 33 of Set 12 | olafsvik
# Processing Record 34 of Set 12 | ketchikan
# Processing Record 35 of Set 12 | along
# Processing Record 36 of Set 12 | takoradi
# Processing Record 37 of Set 12 | puerto cabello
# Processing Record 38 of Set 12 | flagstaff
# Processing Record 39 of Set 12 | omsukchan
# Processing Record 40 of Set 12 | boddam
# Processing Record 41 of Set 12 | nara
# Processing Record 42 of Set 12 | faya
# Processing Record 43 of Set 12 | sinop
# Processing Record 44 of Set 12 | arlit
# Processing Record 45 of Set 12 | tlahualilo
# City not found. Skipping...
# Processing Record 46 of Set 12 | grindavik
# Processing Record 47 of Set 12 | carutapera
# Processing Record 48 of Set 12 | amga
# Processing Record 49 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 50 of Set 12 | porto santo
# Processing Record 1 of Set 13 | estevan
# Processing Record 2 of Set 13 | edgewater
# Processing Record 3 of Set 13 | bozeman
# Processing Record 4 of Set 13 | vaitape
# Processing Record 5 of Set 13 | shieli
# Processing Record 6 of Set 13 | armidale
# Processing Record 7 of Set 13 | sabha
# Processing Record 8 of Set 13 | viedma
# Processing Record 9 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 10 of Set 13 | bonga
# Processing Record 11 of Set 13 | rio grande
# Processing Record 12 of Set 13 | saint augustine
# Processing Record 13 of Set 13 | kiama
# Processing Record 14 of Set 13 | suda
# Processing Record 15 of Set 13 | bonavista
# Processing Record 16 of Set 13 | hanna
# Processing Record 17 of Set 13 | vredendal
# Processing Record 18 of Set 13 | haines junction
# Processing Record 19 of Set 13 | yeppoon
# Processing Record 20 of Set 13 | kapoeta
# Processing Record 21 of Set 13 | roald
# Processing Record 22 of Set 13 | kontagora
# Processing Record 23 of Set 13 | trairi
# Processing Record 24 of Set 13 | makung
# City not found. Skipping...
# Processing Record 25 of Set 13 | hami
# Processing Record 26 of Set 13 | ketchenery
# City not found. Skipping...
# Processing Record 27 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 13 | liku
# Processing Record 29 of Set 13 | gashua
# Processing Record 30 of Set 13 | oistins
# Processing Record 31 of Set 13 | ipixuna
# Processing Record 32 of Set 13 | cabimas
# Processing Record 33 of Set 13 | nome
# Processing Record 34 of Set 13 | satoraljaujhely
# Processing Record 35 of Set 13 | vakhrushev
# Processing Record 36 of Set 13 | karratha
# Processing Record 37 of Set 13 | saint-pierre
# Processing Record 38 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 13 | mattawa
# Processing Record 40 of Set 13 | prince george
# Processing Record 41 of Set 13 | shchelyayur
# City not found. Skipping...
# Processing Record 42 of Set 13 | arman
# Processing Record 43 of Set 13 | markova
# Processing Record 44 of Set 13 | aksarka
# Processing Record 45 of Set 13 | olinda
# Processing Record 46 of Set 13 | fukue
# Processing Record 47 of Set 13 | byron bay
# Processing Record 48 of Set 13 | shangqiu
# Processing Record 49 of Set 13 | arroio grande
# Processing Record 50 of Set 13 | redmond
# Processing Record 1 of Set 14 | ziyang
# Processing Record 2 of Set 14 | bac lieu
# Processing Record 3 of Set 14 | khani
# Processing Record 4 of Set 14 | birnin kebbi
# Processing Record 5 of Set 14 | tutoia
# Processing Record 6 of Set 14 | pangody
# Processing Record 7 of Set 14 | mount gambier
# Processing Record 8 of Set 14 | piacabucu
# Processing Record 9 of Set 14 | ksenyevka
# City not found. Skipping...
# Processing Record 10 of Set 14 | teya
# Processing Record 11 of Set 14 | oranjemund
# Processing Record 12 of Set 14 | launceston
# Processing Record 13 of Set 14 | santa rosa
# Processing Record 14 of Set 14 | mitsamiouli
# Processing Record 15 of Set 14 | igrim
# Processing Record 16 of Set 14 | moengo
# Processing Record 17 of Set 14 | eisenstadt
# Processing Record 18 of Set 14 | harindanga
# Processing Record 19 of Set 14 | tulun
# Processing Record 20 of Set 14 | kvarkeno
# Processing Record 21 of Set 14 | narrabri
# Processing Record 22 of Set 14 | moncagua
# Processing Record 23 of Set 14 | abu dhabi
# Processing Record 24 of Set 14 | qaqortoq
# Processing Record 25 of Set 14 | arinos
# Processing Record 26 of Set 14 | jaboticabal
# Processing Record 27 of Set 14 | umm lajj
# Processing Record 28 of Set 14 | ligayan
# Processing Record 29 of Set 14 | lixourion
# Processing Record 30 of Set 14 | anchorage
# Processing Record 31 of Set 14 | filadelfia
# Processing Record 32 of Set 14 | doha
# Processing Record 33 of Set 14 | novooleksiyivka
# Processing Record 34 of Set 14 | deh rawud
# City not found. Skipping...
# Processing Record 35 of Set 14 | fare
# Processing Record 36 of Set 14 | sault sainte marie
# Processing Record 37 of Set 14 | tadine
# Processing Record 38 of Set 14 | panji
# Processing Record 39 of Set 14 | ontario
# Processing Record 40 of Set 14 | tiruvottiyur
# City not found. Skipping...
# Processing Record 41 of Set 14 | asfi
# Processing Record 42 of Set 14 | seoul
# Processing Record 43 of Set 14 | borogontsy
# Processing Record 44 of Set 14 | itambacuri
# Processing Record 45 of Set 14 | nao-me-toque
# City not found. Skipping...
# Processing Record 46 of Set 14 | sorland
# Processing Record 47 of Set 14 | iranshahr
# Processing Record 48 of Set 14 | adrar
# Processing Record 49 of Set 14 | srednekolymsk
# Processing Record 50 of Set 14 | cocobeach
# Processing Record 1 of Set 15 | maragogi
# Processing Record 2 of Set 15 | xianshuigu
# Processing Record 3 of Set 15 | presidente epitacio
# Processing Record 4 of Set 15 | imbituba
# Processing Record 5 of Set 15 | half moon bay
# Processing Record 6 of Set 15 | palana
# Processing Record 7 of Set 15 | muroto
# Processing Record 8 of Set 15 | victor harbor
# Processing Record 9 of Set 15 | mamallapuram
# Processing Record 10 of Set 15 | kokopo
# Processing Record 11 of Set 15 | masakin
# Processing Record 12 of Set 15 | springbok
# Processing Record 13 of Set 15 | albert lea
# Processing Record 14 of Set 15 | veisiejai
# Processing Record 15 of Set 15 | ihosy
# Processing Record 16 of Set 15 | terra santa
# Processing Record 17 of Set 15 | leland
# Processing Record 18 of Set 15 | havre-saint-pierre
# Processing Record 19 of Set 15 | norden
# Processing Record 20 of Set 15 | polovinnoye
# Processing Record 21 of Set 15 | kemptville
# Processing Record 22 of Set 15 | torbat-e jam
# Processing Record 23 of Set 15 | bidor
# Processing Record 24 of Set 15 | nizwa
# Processing Record 25 of Set 15 | chirongui
# Processing Record 26 of Set 15 | unye
# City not found. Skipping...
# Processing Record 27 of Set 15 | hoquiam
# Processing Record 28 of Set 15 | primalkinskoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 672

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Solnechnyy  50.7214  136.6319      2.05        96          97
# 1          Kapaa  22.0752 -159.3190     78.78        69           0
# 2        Ushuaia -54.8000  -68.3000     47.82        76          90
# 3  Prince Rupert  54.3161 -130.3201     42.89        87         100
# 4        Mataura -46.1927  168.8643     54.48        91         100
# 5   Puerto Ayora  -0.7393  -90.3518     73.83        85          40
# 6    Broken Hill -31.9500  141.4333     93.56        32           0
# 7  Mar Del Plata -38.0023  -57.5575     71.10        79           0
# 8        Rikitea -23.1203 -134.9692     77.52        74           4
# 9      Busselton -33.6500  115.3333     74.05        48          74
#
#    Wind Speed Country Current Description                 Date
# 0        4.97      RU     overcast clouds  2022-01-12 00:09:30
# 1        1.99      US           clear sky  2022-01-12 00:08:01
# 2        2.48      AR     overcast clouds  2022-01-12 00:07:50
# 3        8.05      CA     overcast clouds  2022-01-12 00:08:23
# 4       10.22      NZ     overcast clouds  2022-01-12 00:07:52
# 5        8.90      EC    scattered clouds  2022-01-12 00:08:24
# 6       14.12      AU           clear sky  2022-01-12 00:08:14
# 7        1.99      AR           clear sky  2022-01-12 00:06:14
# 8       18.45      PF           clear sky  2022-01-12 00:07:54
# 9        9.89      AU       broken clouds  2022-01-12 00:08:01

# %%
# Correct the column order
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Date"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Solnechnyy      RU  50.7214  136.6319      2.05        96          97
# 1          Kapaa      US  22.0752 -159.3190     78.78        69           0
# 2        Ushuaia      AR -54.8000  -68.3000     47.82        76          90
# 3  Prince Rupert      CA  54.3161 -130.3201     42.89        87         100
# 4        Mataura      NZ -46.1927  168.8643     54.48        91         100
# 5   Puerto Ayora      EC  -0.7393  -90.3518     73.83        85          40
# 6    Broken Hill      AU -31.9500  141.4333     93.56        32           0
# 7  Mar Del Plata      AR -38.0023  -57.5575     71.10        79           0
# 8        Rikitea      PF -23.1203 -134.9692     77.52        74           4
# 9      Busselton      AU -33.6500  115.3333     74.05        48          74
#
#    Wind Speed Current Description                 Date
# 0        4.97     overcast clouds  2022-01-12 00:09:30
# 1        1.99           clear sky  2022-01-12 00:08:01
# 2        2.48     overcast clouds  2022-01-12 00:07:50
# 3        8.05     overcast clouds  2022-01-12 00:08:23
# 4       10.22     overcast clouds  2022-01-12 00:07:52
# 5        8.90    scattered clouds  2022-01-12 00:08:24
# 6       14.12           clear sky  2022-01-12 00:08:14
# 7        1.99           clear sky  2022-01-12 00:06:14
# 8       18.45           clear sky  2022-01-12 00:07:54
# 9        9.89       broken clouds  2022-01-12 00:08:01

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
